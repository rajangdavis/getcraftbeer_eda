# %% [markdown]
# # EDA
#
# ### Some initial EDA for my beer recommender

# %% [markdown]
# I am only going to probably do look at the data and do some basic plots; these dependencies do that

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
beer_reviews = pd.read_csv("./socialmediadata-beeradvocate/data/beer_reviews.csv")

# %%
beer_reviews.shape
# Out:
# (1586614, 13)

# %%
beer_reviews.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# 3                 German Pilsener            2.5           3.0
# 4  American Double / Imperial IPA            4.0           4.5
#
#                 beer_name  beer_abv  beer_beerid
# 0            Sausa Weizen       5.0        47986
# 1                Red Moon       6.2        48213
# 2  Black Horse Black Beer       6.5        48215
# 3              Sausa Pils       5.0        47969
# 4           Cauldron DIPA       7.7        64883

# %%
beer_reviews.isnull().sum()
# Out:
# brewery_id                0
# brewery_name             15
# review_time               0
# review_overall            0
# review_aroma              0
# review_appearance         0
# review_profilename      348
# beer_style                0
# review_palate             0
# review_taste              0
# beer_name                 0
# beer_abv              67785
# beer_beerid               0
# dtype: int64

# %%
beer_reviews.dtypes
# Out:
# brewery_id              int64
# brewery_name           object
# review_time             int64
# review_overall        float64
# review_aroma          float64
# review_appearance     float64
# review_profilename     object
# beer_style             object
# review_palate         float64
# review_taste          float64
# beer_name              object
# beer_abv              float64
# beer_beerid             int64
# dtype: object

# %%
avg_by_beer_style = beer_reviews.groupby("beer_style")["review_overall","review_aroma","review_appearance","review_palate","review_taste"].mean()
avg_by_beer_style["counts"] = beer_reviews.groupby("beer_style").size()
avg_by_beer_style.sort_values(by="counts", ascending=False).head()
# Out:
#                                   review_overall  review_aroma  \
# beer_style
# American IPA                            3.965221      3.894103
# American Double / Imperial IPA          3.998017      4.097782
# American Pale Ale (APA)                 3.852306      3.657746
# Russian Imperial Stout                  4.023084      4.076576
# American Double / Imperial Stout        4.029820      4.160665
#
#                                   review_appearance  review_palate  \
# beer_style
# American IPA                               3.968525       3.867476
# American Double / Imperial IPA             4.078916       4.023128
# American Pale Ale (APA)                    3.781610       3.684153
# Russian Imperial Stout                     4.210072       4.086922
# American Double / Imperial Stout           4.163633       4.098669
#
#                                   review_taste  counts
# beer_style
# American IPA                          3.922363  117586
# American Double / Imperial IPA        4.091280   85977
# American Pale Ale (APA)               3.721423   63469
# Russian Imperial Stout                4.149569   54129
# American Double / Imperial Stout      4.187230   50705

# %%
avg_by_brewery_name = beer_reviews.groupby("brewery_name")["review_overall","review_aroma","review_appearance","review_palate","review_taste"].mean()
avg_by_brewery_name["counts"] = beer_reviews.groupby("brewery_name").size()
avg_by_brewery_name.sort_values(by="counts", ascending=False).head()
# Out:
#                                     review_overall  review_aroma  \
# brewery_name
# Boston Beer Company (Samuel Adams)        3.689522      3.593107
# Dogfish Head Brewery                      3.836047      3.916945
# Stone Brewing Co.                         4.040268      4.094644
# Sierra Nevada Brewing Co.                 4.056207      3.896682
# Bell's Brewery, Inc.                      3.973066      3.938331
#
#                                     review_appearance  review_palate  \
# brewery_name
# Boston Beer Company (Samuel Adams)           3.809299       3.641365
# Dogfish Head Brewery                         3.943763       3.895860
# Stone Brewing Co.                            4.152422       4.073550
# Sierra Nevada Brewing Co.                    4.096971       3.965184
# Bell's Brewery, Inc.                         3.983724       3.965484
#
#                                     review_taste  counts
# brewery_name
# Boston Beer Company (Samuel Adams)      3.647171   39444
# Dogfish Head Brewery                    3.971350   33839
# Stone Brewing Co.                       4.150608   33066
# Sierra Nevada Brewing Co.               4.028764   28751
# Bell's Brewery, Inc.                    4.011572   25191

# %%
avg_beers_by_brewery_name = beer_reviews.groupby(["brewery_name","beer_style"])["review_overall","review_aroma","review_appearance","review_palate","review_taste"].mean()
avg_beers_by_brewery_name["counts"] = beer_reviews.groupby(["brewery_name","beer_style"]).size()
avg_beers_by_brewery_name.sort_values(by="counts", ascending=False).head(10)
# Out:
#                                                             review_overall  \
# brewery_name              beer_style
# Sierra Nevada Brewing Co. American IPA                            4.150955
# Stone Brewing Co.         American Strong Ale                     4.054657
# Dogfish Head Brewery      American Double / Imperial IPA          3.953045
# Founders Brewing Company  American Double / Imperial Stout        4.399412
# Unibroue                  Belgian Strong Dark Ale                 4.098937
# Anheuser-Busch            Light Lager                             2.468323
# Stone Brewing Co.         American Double / Imperial IPA          4.071805
# Guinness Ltd.             Irish Dry Stout                         3.686925
# Dogfish Head Brewery      American IPA                            4.050170
# Lagunitas Brewing Company American Double / Imperial IPA          4.074852
#
#                                                             review_aroma  \
# brewery_name              beer_style
# Sierra Nevada Brewing Co. American IPA                          4.026592
# Stone Brewing Co.         American Strong Ale                   4.143713
# Dogfish Head Brewery      American Double / Imperial IPA        4.101375
# Founders Brewing Company  American Double / Imperial Stout      4.489618
# Unibroue                  Belgian Strong Dark Ale               4.109987
# Anheuser-Busch            Light Lager                           1.894672
# Stone Brewing Co.         American Double / Imperial IPA        4.237353
# Guinness Ltd.             Irish Dry Stout                       3.356416
# Dogfish Head Brewery      American IPA                          3.922309
# Lagunitas Brewing Company American Double / Imperial IPA        4.128088
#
#                                                             review_appearance  \
# brewery_name              beer_style
# Sierra Nevada Brewing Co. American IPA                               4.212527
# Stone Brewing Co.         American Strong Ale                        4.251497
# Dogfish Head Brewery      American Double / Imperial IPA             4.128815
# Founders Brewing Company  American Double / Imperial Stout           4.380411
# Unibroue                  Belgian Strong Dark Ale                    4.117807
# Anheuser-Busch            Light Lager                                2.119208
# Stone Brewing Co.         American Double / Imperial IPA             4.125509
# Guinness Ltd.             Irish Dry Stout                            4.124939
# Dogfish Head Brewery      American IPA                               3.947151
# Lagunitas Brewing Company American Double / Imperial IPA             4.034832
#
#                                                             review_palate  \
# brewery_name              beer_style
# Sierra Nevada Brewing Co. American IPA                           4.042834
# Stone Brewing Co.         American Strong Ale                    4.155052
# Dogfish Head Brewery      American Double / Imperial IPA         4.064571
# Founders Brewing Company  American Double / Imperial Stout       4.446033
# Unibroue                  Belgian Strong Dark Ale                4.074437
# Anheuser-Busch            Light Lager                            2.043989
# Stone Brewing Co.         American Double / Imperial IPA         4.113882
# Guinness Ltd.             Irish Dry Stout                        3.503632
# Dogfish Head Brewery      American IPA                           3.930102
# Lagunitas Brewing Company American Double / Imperial IPA         3.979496
#
#                                                             review_taste  \
# brewery_name              beer_style
# Sierra Nevada Brewing Co. American IPA                          4.133015
# Stone Brewing Co.         American Strong Ale                   4.253727
# Dogfish Head Brewery      American Double / Imperial IPA        4.160707
# Founders Brewing Company  American Double / Imperial Stout      4.572968
# Unibroue                  Belgian Strong Dark Ale               4.232694
# Anheuser-Busch            Light Lager                           1.966197
# Stone Brewing Co.         American Double / Imperial IPA        4.232079
# Guinness Ltd.             Irish Dry Stout                       3.472276
# Dogfish Head Brewery      American IPA                          4.006941
# Lagunitas Brewing Company American Double / Imperial IPA        4.088315
#
#                                                             counts
# brewery_name              beer_style
# Sierra Nevada Brewing Co. American IPA                        9420
# Stone Brewing Co.         American Strong Ale                 7849
# Dogfish Head Brewery      American Double / Imperial IPA      7635
# Founders Brewing Company  American Double / Imperial Stout    5105
# Unibroue                  Belgian Strong Dark Ale             4796
# Anheuser-Busch            Light Lager                         4467
# Stone Brewing Co.         American Double / Imperial IPA      4171
# Guinness Ltd.             Irish Dry Stout                     4130
# Dogfish Head Brewery      American IPA                        4106
# Lagunitas Brewing Company American Double / Imperial IPA      4048

# %%
avg_by_beer_name = beer_reviews.groupby(["beer_name","brewery_name"])["review_overall","review_aroma","review_appearance","review_palate","review_taste"].mean()
avg_by_beer_name["counts"] = beer_reviews.groupby(["beer_name","brewery_name"]).size()
avg_by_beer_name.sort_values(by="counts", ascending=False).head()
# Out:
#                                                                review_overall  \
# beer_name                           brewery_name
# 90 Minute IPA                       Dogfish Head Brewery             4.145745
# Old Rasputin Russian Imperial Stout North Coast Brewing Co.          4.174221
# Sierra Nevada Celebration Ale       Sierra Nevada Brewing Co.        4.168667
# Two Hearted Ale                     Bell's Brewery, Inc.             4.329729
# Arrogant Bastard Ale                Stone Brewing Co.                4.078402
#
#                                                                review_aroma  \
# beer_name                           brewery_name
# 90 Minute IPA                       Dogfish Head Brewery           4.213526
# Old Rasputin Russian Imperial Stout North Coast Brewing Co.        4.198650
# Sierra Nevada Celebration Ale       Sierra Nevada Brewing Co.      4.082333
# Two Hearted Ale                     Bell's Brewery, Inc.           4.266496
# Arrogant Bastard Ale                Stone Brewing Co.              4.119268
#
#                                                                review_appearance  \
# beer_name                           brewery_name
# 90 Minute IPA                       Dogfish Head Brewery                4.192097
# Old Rasputin Russian Imperial Stout North Coast Brewing Co.             4.373995
# Sierra Nevada Celebration Ale       Sierra Nevada Brewing Co.           4.225167
# Two Hearted Ale                     Bell's Brewery, Inc.                4.153959
# Arrogant Bastard Ale                Stone Brewing Co.                   4.296413
#
#                                                                review_palate  \
# beer_name                           brewery_name
# 90 Minute IPA                       Dogfish Head Brewery            4.181763
# Old Rasputin Russian Imperial Stout North Coast Brewing Co.         4.231758
# Sierra Nevada Celebration Ale       Sierra Nevada Brewing Co.       4.076000
# Two Hearted Ale                     Bell's Brewery, Inc.            4.138746
# Arrogant Bastard Ale                Stone Brewing Co.               4.143121
#
#                                                                review_taste  \
# beer_name                           brewery_name
# 90 Minute IPA                       Dogfish Head Brewery           4.325988
# Old Rasputin Russian Imperial Stout North Coast Brewing Co.        4.342173
# Sierra Nevada Celebration Ale       Sierra Nevada Brewing Co.      4.190000
# Two Hearted Ale                     Bell's Brewery, Inc.           4.318915
# Arrogant Bastard Ale                Stone Brewing Co.              4.278846
#
#                                                                counts
# beer_name                           brewery_name
# 90 Minute IPA                       Dogfish Head Brewery         3290
# Old Rasputin Russian Imperial Stout North Coast Brewing Co.      3111
# Sierra Nevada Celebration Ale       Sierra Nevada Brewing Co.    3000
# Two Hearted Ale                     Bell's Brewery, Inc.         2728
# Arrogant Bastard Ale                Stone Brewing Co.            2704

# %%
user_reviews = beer_reviews.groupby(["review_profilename"])["review_overall","review_aroma","review_appearance","review_palate","review_taste"].mean()
user_reviews["counts"] = beer_reviews.groupby(["review_profilename"]).size()
user_reviews.counts.mean()
# Out:
# 47.511486506724175

# %%
beer_reviews.corr()
# Out:
#                    brewery_id  review_time  review_overall  review_aroma  \
# brewery_id           1.000000     0.220954       -0.009331      0.019069
# review_time          0.220954     1.000000        0.028724      0.067453
# review_overall      -0.009331     0.028724        1.000000      0.616013
# review_aroma         0.019069     0.067453        0.616013      1.000000
# review_appearance    0.001993     0.058233        0.501732      0.561029
# review_palate       -0.000499     0.057247        0.701914      0.616947
# review_taste        -0.002672     0.044498        0.789816      0.716776
# beer_abv             0.063731     0.144885        0.138512      0.332570
# beer_beerid          0.424097     0.461535        0.003794      0.077669
#
#                    review_appearance  review_palate  review_taste  beer_abv  \
# brewery_id                  0.001993      -0.000499     -0.002672  0.063731
# review_time                 0.058233       0.057247      0.044498  0.144885
# review_overall              0.501732       0.701914      0.789816  0.138512
# review_aroma                0.561029       0.616947      0.716776  0.332570
# review_appearance           1.000000       0.566634      0.546980  0.263941
# review_palate               0.566634       1.000000      0.734135  0.286711
# review_taste                0.546980       0.734135      1.000000  0.290827
# beer_abv                    0.263941       0.286711      0.290827  1.000000
# beer_beerid                 0.054794       0.044510      0.030402  0.201818
#
#                    beer_beerid
# brewery_id            0.424097
# review_time           0.461535
# review_overall        0.003794
# review_aroma          0.077669
# review_appearance     0.054794
# review_palate         0.044510
# review_taste          0.030402
# beer_abv              0.201818
# beer_beerid           1.000000

# %%
import seaborn as sns
plt.figure(figsize=(12,12))
sns.heatmap(beer_reviews.corr()[(beer_reviews.corr() > .5) | (beer_reviews.corr() < -.5)], annot=True)

# %%
text_reviews = pd.read_csv("./petergensler-beer-advocate-reviews/BeerAdvocate-000.csv")

# %%
text_reviews.head()
# Out:
#    beer_ABV  beer_beerId  beer_brewerId               beer_name  \
# 0       5.0        47986          10325            Sausa Weizen
# 1       6.2        48213          10325                Red Moon
# 2       6.5        48215          10325  Black Horse Black Beer
# 3       5.0        47969          10325              Sausa Pils
# 4       7.7        64883           1075           Cauldron DIPA
#
#                        beer_style  review_appearance  review_aroma  \
# 0                      Hefeweizen                2.5           2.0
# 1              English Strong Ale                3.0           2.5
# 2          Foreign / Export Stout                3.0           2.5
# 3                 German Pilsener                3.5           3.0
# 4  American Double / Imperial IPA                4.0           4.5
#
#    review_overall  review_palate review_profileName  review_taste  \
# 0             1.5            1.5            stcules           1.5
# 1             3.0            3.0            stcules           3.0
# 2             3.0            3.0            stcules           3.0
# 3             3.0            2.5            stcules           3.0
# 4             4.0            4.0     johnmichaelsen           4.5
#
#                                          review_text  review_time
# 0  A lot of foam. But a lot. In the smell some ba...   1234817823
# 1  Dark red color, light beige foam, average. In ...   1235915097
# 2  Almost totally black. Beige foam, quite compac...   1235916604
# 3  Golden yellow color. White, compact foam, quit...   1234725145
# 4  According to the website, the style for the Ca...   1293735206

# %%
text_reviews.shape
# Out:
# (528870, 13)

# %%
text_reviews.isnull().sum()
# Out:
# beer_ABV              20280
# beer_beerId               0
# beer_brewerId             0
# beer_name                 0
# beer_style                0
# review_appearance         0
# review_aroma              0
# review_overall            0
# review_palate             0
# review_profileName      115
# review_taste              0
# review_text             119
# review_time               0
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
text_reviews.dropna(inplace=True)

# %%
# TODO do some count_vectorization stuff

# %%
brewery_json = pd.read_json("./scrape_ba/breweries.json")

# %%
brewery_json.head()
# Out:
#                 address             city        country  \
# 0       3090 Shirley Dr          Jackson  United States
# 1     100 W.Portage Ave  Sault Ste Marie  United States
# 2        1638 142nd Ave             Dorr  United States
# 3  1310 W Washington St       Greenville  United States
# 4           15 Cross St        Ypsilanti  United States
#
#                            features  \
# 0          Brewery, Bar, Beer-to-go
# 1              Brewery, Bar, Eatery
# 2              Brewery, Bar, Eatery
# 3  Brewery, Bar, Eatery, Beer-to-go
# 4                      Brewery, Bar
#
#                                                link  \
# 0  https://www.beeradvocate.com/beer/profile/34957/
# 1  https://www.beeradvocate.com/beer/profile/46669/
# 2  https://www.beeradvocate.com/beer/profile/48559/
# 3  https://www.beeradvocate.com/beer/profile/32165/
# 4  https://www.beeradvocate.com/beer/profile/53225/
#
#                              name    phone_number     state     zipcode
# 0             127 Brewing Company  (517) 258-1346  Michigan  49201-7010
# 1  1668 Winery & Lockside Brewery  (906) 259-5035  Michigan       49783
# 2             5 Lakes Brewing Co.  (616) 359-9555  Michigan       49323
# 3            57 Brew Pub & Bistro  (616) 712-6226  Michigan  48838-2190
# 4             734 Brewing Company  (734) 340-3468  Michigan       48198

# %%
brewery_json.shape
# Out:
# (7232, 9)

# %%
brewery_json.groupby("state")["state"].count().sort_values(ascending=False).head(10)
# Out:
# state
# California        850
# New York          405
# Washington        382
# Colorado          374
# Pennsylvania      346
# Michigan          314
# Florida           297
# Texas             281
# North Carolina    273
# Oregon            268
# Name: state, dtype: int64

# %%
brewery_json.groupby("features")["features"].count().sort_values(ascending=False).head()
# Out:
# features
# Brewery, Bar, Beer-to-go            2141
# Brewery, Bar, Eatery, Beer-to-go    1571
# Brewery, Bar, Eatery                1169
# Brewery                              989
# Brewery, Bar                         920
# Name: features, dtype: int64
