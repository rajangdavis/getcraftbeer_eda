# %%
# https://towardsdatascience.com/multi-class-text-classification-with-scikit-learn-12f1e60e0a9f

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from sqlalchemy import create_engine

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.feature_selection import chi2
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics import accuracy_score

# %%
def clean_text(corpus):
    replace_dict = {
        "â€œ":"\"", 
        "â€�":"\"", 
        "Ã¨":"è",
        "Ã¶":"ö",
        "Ã¼s":"ü",
        "â€“":"-",
        "â€”":"-",
        "Ã©":"é",
        "â€™":"'"
    }
    for term_to_replace, replacement_value in replace_dict.items():
        corpus = corpus.replace(term_to_replace, replacement_value)
    return corpus

# %%
pg_pass = os.environ['BEER_DB']
engine = create_engine(pg_pass)
pd.read_sql("SELECT tablename FROM pg_catalog.pg_tables WHERE schemaname='public' LIMIT 5", con=engine)
# Out:
#          tablename
# 0  spatial_ref_sys
# 1    SequelizeMeta
# 2        breweries
# 3           styles
# 4          reviews

# %%
styles = pd.read_sql("SELECT name, description FROM styles", con=engine)

# %%
styles.head()
# Out:
#                       name                                        description
# 0           Belgian Dubbel  The Belgian Dubbel is a rich, malty beer with ...
# 1             American IPA  Today's American IPA is a different soul from ...
# 2           German Pilsner  A classic German-style Pilsner is straw to pal...
# 3  American Pale Ale (APA)  Originally British in origin, this style is no...
# 4    American Imperial IPA  We have west coast American brewers to thank f...

# %%
reviews_by_style_count = """
SELECT
styles.name,
COUNT(styles.name)
FROM reviews, styles, beers
WHERE reviews.beer_id = beers.id
AND beers.style_id = styles.id
AND reviews.review_text IS NOT NULL
GROUP BY styles.name
HAVING COUNT(styles.name) > 10000
ORDER BY COUNT DESC;
"""

reviews_count = pd.read_sql(reviews_by_style_count, con=engine)

# %%
reviews_count.shape
# Out:
# (32, 2)

# %%
reviews_count['count']
# Out:
# 0     206049
# 1     108756
# 2      77559
# 3      58397
# 4      48998
# 5      43526
# 6      41004
# 7      40617
# 8      30635
# 9      30309
# 10     23162
# 11     22015
# 12     21598
# 13     20227
# 14     19898
# 15     19061
# 16     18918
# 17     18360
# 18     15950
# 19     15267
# 20     14382
# 21     14330
# 22     14182
# 23     13884
# 24     13368
# 25     12798
# 26     11746
# 27     11547
# 28     11409
# 29     11230
# 30     10633
# 31     10498
# Name: count, dtype: int64

# %%
reviews_count.head()
# Out:
#                       name   count
# 0             American IPA  206049
# 1    American Imperial IPA  108756
# 2  American Pale Ale (APA)   77559
# 3  American Imperial Stout   58397
# 4           Belgian Saison   48998

# %%
reviews_count.tail()
# Out:
#                       name  count
# 27  Scotch Ale / Wee Heavy  11547
# 28       Bohemian Pilsener  11409
# 29          American Lager  11230
# 30            Leipzig Gose  10633
# 31       English Brown Ale  10498

# %%
reviews_count.plot(kind="bar", x="name", figsize=(10,8))

# %%
reviews_query = """
SELECT 
reviews.review_text,
styles.name as target,
styles.id as target_id
FROM reviews, styles, beers
WHERE reviews.beer_id = beers.id
AND beers.style_id = styles.id
AND reviews.review_text IS NOT NULL
AND reviews.review_text !=''
LIMIT 15000;
"""

reviews = pd.read_sql(reviews_query, con=engine)
reviews.head()
# Out:
#                                          review_text                   target  \
# 0  A very drinkable X Pale Ale. It poured a light...            German Kölsch
# 1  This was a "special brew" on tap at the BJ's i...            German Kölsch
# 2  This was a tough beer to rate. It was pretty g...  American Pale Ale (APA)
# 3  Pours with a wispy pale head that sits atop a ...  American Pale Ale (APA)
# 4  Sampled on tap at the Las Vegas (Summerlin) lo...             American IPA
#
#    target_id
# 0         12
# 1         12
# 2          4
# 3          4
# 4          2

# %%
tfidf = TfidfVectorizer(min_df=.05, max_df=0.5, ngram_range=(1, 2), stop_words='english')

features = tfidf.fit_transform(reviews.review_text).toarray()
labels = reviews.target_id
features.shape
# Out:
# (15000, 211)

# %%
number_of_terms = 2

styles_to_id = dict(zip(reviews.target, reviews.target_id))

for style, style_id in sorted(styles_to_id.items()):
    features_chi2 = chi2(features, labels == style_id)    
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print(f"{style}:")
    print(f"Most correlated unigrams: { ' '.join(unigrams[-number_of_terms:]) }") 
    print(f"Most correlated bigrams: { ', '.join(bigrams[-number_of_terms:])  }")
    [print() for _ in range(4)]
# Out:
# American Adjunct Lager:
# Most correlated unigrams: yellow fresh
# Most correlated bigrams: pint glass, medium bodied
#
#
#
#
# American Amber / Red Ale:
# Most correlated unigrams: ipa earthy
# Most correlated bigrams: medium body, medium bodied
#
#
#
#
# American Amber / Red Lager:
# Most correlated unigrams: makes say
# Most correlated bigrams: amber color, pint glass
#
#
#
#
# American Barleywine:
# Most correlated unigrams: yeast wheat
# Most correlated bigrams: white head, tan head
#
#
#
#
# American Black Ale:
# Most correlated unigrams: floral alcohol
# Most correlated bigrams: medium body, medium bodied
#
#
#
#
# American Blonde Ale:
# Most correlated unigrams: cloudy wheat
# Most correlated bigrams: tan head, white head
#
#
#
#
# American Brett:
# Most correlated unigrams: coffee chocolate
# Most correlated bigrams: tan head, medium body
#
#
#
#
# American Brown Ale:
# Most correlated unigrams: wheat fruit
# Most correlated bigrams: amber color, sam adams
#
#
#
#
# American Brut IPA:
# Most correlated unigrams: got heavy
# Most correlated bigrams: medium bodied, white head
#
#
#
#
# American Cream Ale:
# Most correlated unigrams: fresh actually
# Most correlated bigrams: tan head, amber color
#
#
#
#
# American IPA:
# Most correlated unigrams: wheat honey
# Most correlated bigrams: white head, amber color
#
#
#
#
# American Imperial IPA:
# Most correlated unigrams: belgian sugar
# Most correlated bigrams: sam adams, amber color
#
#
#
#
# American Imperial Pilsner:
# Most correlated unigrams: fresh isn
# Most correlated bigrams: 12 oz, oz bottle
#
#
#
#
# American Imperial Porter:
# Most correlated unigrams: dark chocolate
# Most correlated bigrams: medium bodied, tan head
#
#
#
#
# American Imperial Red Ale:
# Most correlated unigrams: black coffee
# Most correlated bigrams: amber color, white head
#
#
#
#
# American Imperial Stout:
# Most correlated unigrams: dry bubbles
# Most correlated bigrams: tan head, oz bottle
#
#
#
#
# American Lager:
# Most correlated unigrams: grapefruit pine
# Most correlated bigrams: tan head, sam adams
#
#
#
#
# American Light Lager:
# Most correlated unigrams: hops hop
# Most correlated bigrams: oz bottle, pint glass
#
#
#
#
# American Malt Liquor:
# Most correlated unigrams: floral average
# Most correlated bigrams: medium bodied, white head
#
#
#
#
# American Pale Ale (APA):
# Most correlated unigrams: honey floral
# Most correlated bigrams: oz bottle, 12 oz
#
#
#
#
# American Pale Wheat Ale:
# Most correlated unigrams: ale pale
# Most correlated bigrams: white head, tan head
#
#
#
#
# American Porter:
# Most correlated unigrams: yeast belgian
# Most correlated bigrams: oz bottle, sam adams
#
#
#
#
# American Stout:
# Most correlated unigrams: chocolate coffee
# Most correlated bigrams: sam adams, white head
#
#
#
#
# American Strong Ale:
# Most correlated unigrams: lemon lager
# Most correlated bigrams: white head, sam adams
#
#
#
#
# American Wild Ale:
# Most correlated unigrams: pine grapefruit
# Most correlated bigrams: pint glass, sam adams
#
#
#
#
# Baltic Porter:
# Most correlated unigrams: caramel toffee
# Most correlated bigrams: oz bottle, amber color
#
#
#
#
# Belgian Blonde Ale :
# Most correlated unigrams: pint big
# Most correlated bigrams: white head, pint glass
#
#
#
#
# Belgian Dark Ale:
# Most correlated unigrams: probably wheat
# Most correlated bigrams: amber color, medium bodied
#
#
#
#
# Belgian Dubbel:
# Most correlated unigrams: finishes red
# Most correlated bigrams: white head, medium bodied
#
#
#
#
# Belgian IPA:
# Most correlated unigrams: ale pale
# Most correlated bigrams: tan head, sam adams
#
#
#
#
# Belgian Pale Ale:
# Most correlated unigrams: light honey
# Most correlated bigrams: tan head, sam adams
#
#
#
#
# Belgian Quadrupel (Quad):
# Most correlated unigrams: beers low
# Most correlated bigrams: pint glass, sam adams
#
#
#
#
# Belgian Saison:
# Most correlated unigrams: like interesting
# Most correlated bigrams: tan head, amber color
#
#
#
#
# Belgian Strong Dark Ale:
# Most correlated unigrams: somewhat high
# Most correlated bigrams: tan head, medium bodied
#
#
#
#
# Belgian Strong Pale Ale:
# Most correlated unigrams: wheat yellow
# Most correlated bigrams: white head, sam adams
#
#
#
#
# Belgian Tripel:
# Most correlated unigrams: chocolate coffee
# Most correlated bigrams: white head, tan head
#
#
#
#
# Belgian Witbier:
# Most correlated unigrams: honey lemon
# Most correlated bigrams: amber color, tan head
#
#
#
#
# Berliner Weisse:
# Most correlated unigrams: ipa pine
# Most correlated bigrams: amber color, medium bodied
#
#
#
#
# Bohemian Pilsener:
# Most correlated unigrams: sip belgian
# Most correlated bigrams: 12 oz, sam adams
#
#
#
#
# British Barleywine:
# Most correlated unigrams: better yellow
# Most correlated bigrams: sam adams, amber color
#
#
#
#
# California Common / Steam Beer:
# Most correlated unigrams: grapefruit lemon
# Most correlated bigrams: medium bodied, white head
#
#
#
#
# Chile Beer:
# Most correlated unigrams: big toasted
# Most correlated bigrams: white head, tan head
#
#
#
#
# English Brown Ale:
# Most correlated unigrams: tan wheat
# Most correlated bigrams: amber color, sam adams
#
#
#
#
# English Dark Mild Ale:
# Most correlated unigrams: pleasant ipa
# Most correlated bigrams: white head, tan head
#
#
#
#
# English Extra Special / Strong Bitter (ESB):
# Most correlated unigrams: way foam
# Most correlated bigrams: sam adams, amber color
#
#
#
#
# English India Pale Ale (IPA):
# Most correlated unigrams: time malt
# Most correlated bigrams: sam adams, amber color
#
#
#
#
# English Oatmeal Stout:
# Most correlated unigrams: refreshing wheat
# Most correlated bigrams: sam adams, tan head
#
#
#
#
# English Old Ale:
# Most correlated unigrams: roasted going
# Most correlated bigrams: white head, medium body
#
#
#
#
# English Pale Ale:
# Most correlated unigrams: refreshing pale
# Most correlated bigrams: medium bodied, white head
#
#
#
#
# English Pale Mild Ale:
# Most correlated unigrams: ipa pine
# Most correlated bigrams: medium bodied, medium body
#
#
#
#
# English Porter:
# Most correlated unigrams: roasted honey
# Most correlated bigrams: white head, sam adams
#
#
#
#
# English Strong Ale:
# Most correlated unigrams: orange lemon
# Most correlated bigrams: tan head, sam adams
#
#
#
#
# English Sweet / Milk Stout:
# Most correlated unigrams: belgian pale
# Most correlated bigrams: oz bottle, 12 oz
#
#
#
#
# European Export / Dortmunder:
# Most correlated unigrams: coffee chocolate
# Most correlated bigrams: tan head, sam adams
#
#
#
#
# Fruit and Field Beer:
# Most correlated unigrams: amber lager
# Most correlated bigrams: sam adams, amber color
#
#
#
#
# German Altbier:
# Most correlated unigrams: hoppy ipa
# Most correlated bigrams: pint glass, amber color
#
#
#
#
# German Bock:
# Most correlated unigrams: didn chocolate
# Most correlated bigrams: pint glass, sam adams
#
#
#
#
# German Doppelbock:
# Most correlated unigrams: chocolate coffee
# Most correlated bigrams: amber color, white head
#
#
#
#
# German Dunkelweizen:
# Most correlated unigrams: yeast belgian
# Most correlated bigrams: amber color, white head
#
#
#
#
# German Hefeweizen:
# Most correlated unigrams: black alcohol
# Most correlated bigrams: medium bodied, white head
#
#
#
#
# German Helles:
# Most correlated unigrams: earthy lager
# Most correlated bigrams: medium bodied, amber color
#
#
#
#
# German Kellerbier / Zwickelbier:
# Most correlated unigrams: abv ipa
# Most correlated bigrams: medium body, medium bodied
#
#
#
#
# German Kölsch:
# Most correlated unigrams: fresh coffee
# Most correlated bigrams: tan head, amber color
#
#
#
#
# German Maibock:
# Most correlated unigrams: bready subtle
# Most correlated bigrams: medium body, amber color
#
#
#
#
# German Märzen / Oktoberfest:
# Most correlated unigrams: golden lager
# Most correlated bigrams: tan head, white head
#
#
#
#
# German Pilsner:
# Most correlated unigrams: spice orange
# Most correlated bigrams: sam adams, white head
#
#
#
#
# German Rauchbier:
# Most correlated unigrams: roasted black
# Most correlated bigrams: white head, sam adams
#
#
#
#
# German Schwarzbier:
# Most correlated unigrams: lager wheat
# Most correlated bigrams: amber color, sam adams
#
#
#
#
# Herb and Spice Beer:
# Most correlated unigrams: solid chocolate
# Most correlated bigrams: tan head, medium body
#
#
#
#
# Irish Dry Stout:
# Most correlated unigrams: ale brown
# Most correlated bigrams: amber color, sam adams
#
#
#
#
# Irish Red Ale:
# Most correlated unigrams: deep chocolate
# Most correlated bigrams: sam adams, amber color
#
#
#
#
# Leipzig Gose:
# Most correlated unigrams: toasted great
# Most correlated bigrams: medium bodied, white head
#
#
#
#
# Low Alcohol Beer:
# Most correlated unigrams: carbonated does
# Most correlated bigrams: medium bodied, white head
#
#
#
#
# New England IPA:
# Most correlated unigrams: bread coffee
# Most correlated bigrams: pint glass, tan head
#
#
#
#
# Pumpkin Beer:
# Most correlated unigrams: chocolate black
# Most correlated bigrams: white head, tan head
#
#
#
#
# Russian Imperial Stout:
# Most correlated unigrams: coffee fruit
# Most correlated bigrams: amber color, sam adams
#
#
#
#
# Rye Beer:
# Most correlated unigrams: lemon honey
# Most correlated bigrams: amber color, tan head
#
#
#
#
# Scotch Ale / Wee Heavy:
# Most correlated unigrams: low lemon
# Most correlated bigrams: sam adams, white head
#
#
#
#
# Scottish Ale:
# Most correlated unigrams: spice brown
# Most correlated bigrams: tan head, sam adams
#
#
#
#
# Scottish Gruit / Ancient Herbed Ale:
# Most correlated unigrams: fades dry
# Most correlated bigrams: pint glass, medium body
#
#
#
#
# Smoke Beer:
# Most correlated unigrams: right fresh
# Most correlated bigrams: medium bodied, white head
# Smoke Porter:
# Most correlated unigrams: bready fresh
# Most correlated bigrams: medium bodied, tan head
#
#
#
#
# Vienna Lager:
# Most correlated unigrams: yeast belgian
# Most correlated bigrams: amber color, pint glass
#
#
#
#
# Winter Warmer:
# Most correlated unigrams: low tastes
# Most correlated bigrams: white head, amber color

# %%
X_train, X_test, y_train, y_test = train_test_split(reviews.review_text, reviews.target_id, random_state = 42)

for i in np.linspace(.5,.95,10):
    for j in np.linspace(0.05,0.2,10):
        tfidf = TfidfVectorizer(stop_words="english", max_df=i, min_df=j)
        X_train_tfidf = tfidf.fit_transform(X_train)
        mnb = MultinomialNB().fit(X_train_tfidf, y_train)
        bnb = BernoulliNB().fit(X_train_tfidf, y_train)

        mnb_predictions = mnb.predict(tfidf.transform(X_test))
        bnb_predictions = bnb.predict(tfidf.transform(X_test))

        mnb_acc_score = accuracy_score(y_test, mnb_predictions)
        print(f"Multinomial Naive Bayes Classifier with tfidf max_df: {i} and min_df: {j}")
        print(f"Score is: {mnb_acc_score}")
        [print() for _ in range(4)]
        
        bnb_acc_score = accuracy_score(y_test, bnb_predictions)
        print(f"Bernoulli Naive Bayes Classifier with tfidf max_df: {i} and min_df: {j}")
        print(f"Score is: {bnb_acc_score}")
        [print() for _ in range(4)]
# Out:
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.05
# Score is: 0.2792
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.05
# Score is: 0.2826666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.06666666666666668
# Score is: 0.2584
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.06666666666666668
# Score is: 0.26213333333333333
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.08333333333333334
# Score is: 0.2432
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.08333333333333334
# Score is: 0.25493333333333335
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.1
# Score is: 0.22746666666666668
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.1
# Score is: 0.23466666666666666
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.11666666666666668
# Score is: 0.20026666666666668
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.11666666666666668
# Score is: 0.212
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.13333333333333336
# Score is: 0.19653333333333334
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.13333333333333336
# Score is: 0.20213333333333333
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.15000000000000002
# Score is: 0.19306666666666666
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.15000000000000002
# Score is: 0.19706666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.16666666666666669
# Score is: 0.18853333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.16666666666666669
# Score is: 0.18933333333333333
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.18333333333333335
# Score is: 0.18773333333333334
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.18333333333333335
# Score is: 0.1816
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.2
# Score is: 0.18453333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.5 and min_df: 0.2
# Score is: 0.17226666666666668
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.05
# Score is: 0.2789333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.05
# Score is: 0.2826666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.06666666666666668
# Score is: 0.2581333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.06666666666666668
# Score is: 0.26213333333333333
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.08333333333333334
# Score is: 0.24373333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.08333333333333334
# Score is: 0.2517333333333333
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.1
# Score is: 0.2272
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.1
# Score is: 0.23866666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.11666666666666668
# Score is: 0.1992
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.11666666666666668
# Score is: 0.21066666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.13333333333333336
# Score is: 0.19653333333333334
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.13333333333333336
# Score is: 0.2048
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.15000000000000002
# Score is: 0.19333333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.15000000000000002
# Score is: 0.19653333333333334
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.16666666666666669
# Score is: 0.1896
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.16666666666666669
# Score is: 0.1888
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.18333333333333335
# Score is: 0.18773333333333334
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.18333333333333335
# Score is: 0.17813333333333334
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.2
# Score is: 0.18213333333333334
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.55 and min_df: 0.2
# Score is: 0.16853333333333334
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.05
# Score is: 0.2789333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.05
# Score is: 0.2826666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.06666666666666668
# Score is: 0.2581333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.06666666666666668
# Score is: 0.26213333333333333
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.08333333333333334
# Score is: 0.24373333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.08333333333333334
# Score is: 0.2517333333333333
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.1
# Score is: 0.2272
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.1
# Score is: 0.23866666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.11666666666666668
# Score is: 0.1992
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.11666666666666668
# Score is: 0.21066666666666667
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.13333333333333336
# Score is: 0.19653333333333334
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.13333333333333336
# Score is: 0.2048
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.15000000000000002
# Score is: 0.19333333333333333
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.15000000000000002
# Score is: 0.19653333333333334
#
#
#
#
# Multinomial Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.16666666666666669
# Score is: 0.1896
#
#
#
#
# Bernoulli Naive Bayes Classifier with tfidf max_df: 0.6 and min_df: 0.16666666666666669
# Score is: 0.1888
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-363addab0c8b> in <module>
#       4     for j in np.linspace(0.05,0.2,10):
#       5         tfidf = TfidfVectorizer(stop_words="english", max_df=i, min_df=j)
# ----> 6         X_train_tfidf = tfidf.fit_transform(X_train)
#       7         mnb = MultinomialNB().fit(X_train_tfidf, y_train)
#       8         bnb = BernoulliNB().fit(X_train_tfidf, y_train)
#
# c:\python36\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1379             Tf-idf-weighted document-term matrix.
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#    1383         # X is already a transformed view of raw_documents so
#
# c:\python36\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# c:\python36\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     803             j_indices.extend(feature_counter.keys())
#     804             values.extend(feature_counter.values())
# --> 805             indptr.append(len(j_indices))
#     806
#     807         if not fixed_vocab:
#
# KeyboardInterrupt:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
import seaborn as sns

# This is one of the
# most gangster pieces of code
# I have ever seen

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=42),
]

CV = 5

cv_df = pd.DataFrame(index=range(CV * len(models)))

entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
    
    # What is going on here?
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))

cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# c:\python36\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# c:\python36\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# c:\python36\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# c:\python36\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %%
cv_df.groupby('model_name').accuracy.mean()

# How about a binary classification?

# https://www.businessinsider.com/everything-you-need-to-know-about-beer-in-one-chart-2015-8
# https://machinelearningmastery.com/tactics-to-combat-imbalanced-classes-in-your-machine-learning-dataset/
# Out:
# model_name
# LinearSVC                 0.269181
# LogisticRegression        0.270094
# MultinomialNB             0.221779
# RandomForestClassifier    0.193174
# Name: accuracy, dtype: float64
